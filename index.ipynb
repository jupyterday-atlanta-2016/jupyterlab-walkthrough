# %%
import pandas
pandas.read_csv('iris.csv')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
import json

with open('parks.geojson') as f:
    s = json.loads(f.read())

# %%
s
# Out:
# {'features': [{'geometry': {'coordinates': [-97.719833, 30.282255],
#     'type': 'Point'},
#    'id': 1,
#    'properties': {'': '',
#     'ACREAGE': 1.85,
#     'AREA': 'Northeast',
#     'ID': 1,
#     'Notes': '',
#     'PARK ADDRESS SERVICE': '2100 Alamo St., Austin, Texas',
#     'PARK NAME': 'Alamo Pocket Park',
#     'Park Type': 'Pocket Park',
#     'Zip': 78722,
#     'geo_accuracy': 'house',
#     'geo_latitude': 30.282255,
#     'geo_longitude': -97.719833},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-97.6965498345626, 30.4145626464157],
#     'type': 'Point'},
#    'id': 2,
#    'properties': {'': '',
#     'ACREAGE': 1.91,
#     'AREA': 'Northwest',
#     'ID': 2,
#     'Notes': '',
#     'PARK ADDRESS SERVICE': '12444 Lamplight Village Ave., Austin, Texas',
#     'PARK NAME': 'Alderbrook Pocket Park',
#     'Park Type': 'Pocket Park',
#     'Zip': 78758,
#     'geo_accuracy': 'house',
#     'geo_latitude': 30.4145626464157,
# ...
